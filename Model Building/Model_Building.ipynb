# %% [markdown]
# ### Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the Dataset

# %%
df=pd.read_csv('Car_Performance.csv')

# %% [markdown]
# ### Data Analysis

# %%
df.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
# 5  15.0          8         429.0         198    4341          10.0
# 6  14.0          8         454.0         220    4354           9.0
# 7  14.0          8         440.0         215    4312           8.5
# 8  14.0          8         455.0         225    4425          10.0
# 9  15.0          8         390.0         190    3850           8.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino
# 5          70       1           ford galaxie 500
# 6          70       1           chevrolet impala
# 7          70       1          plymouth fury iii
# 8          70       1           pontiac catalina
# 9          70       1         amc ambassador dpl

# %%
df.shape
# Out:
# (398, 9)

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    int64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 28.1+ KB

# %%
df.nunique()
# Out:
# mpg             129
# cylinders         5
# displacement     82
# horsepower       93
# weight          351
# acceleration     95
# model year       13
# origin            3
# car name        305
# dtype: int64

# %%
df.origin.unique()
# Out:
# array([1, 3, 2])

# %% [markdown]
# ### Handiling the Missing Values

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
# There is no Null Value in the data set

# %% [markdown]
# ### Lable encoding

# %%
# There is no Categorial value other than the car name (car name is not used for the performance predecting so we can drop the car name column), so we need not to do the label encoding

# %% [markdown]
# ### Droping the car name column

# %%
df=df.iloc[:,:-1]

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
#
#    model year  origin
# 0          70       1
# 1          70       1
# 2          70       1
# 3          70       1
# 4          70       1

# %% [markdown]
# ### Splitting the dataset into dependent and independent Variable

# %%
x=df.iloc[:,1:]

# %%
y=df.iloc[:,0]

# %%
x.head()
# Out:
#    cylinders  displacement  horsepower  weight  acceleration  model year  \
# 0          8         307.0         130    3504          12.0          70
# 1          8         350.0         165    3693          11.5          70
# 2          8         318.0         150    3436          11.0          70
# 3          8         304.0         150    3433          12.0          70
# 4          8         302.0         140    3449          10.5          70
#
#    origin
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
y.head()
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %% [markdown]
# ### Splitting the dataset into train and test

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((318, 7), (80, 7), (318,), (80,))

# %% [markdown]
# ### Normalizing the values

# %%
from sklearn.preprocessing import StandardScaler
sd = StandardScaler()
x_train=sd.fit_transform(x_train)
x_test=sd.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-0.85657842, -0.8326335 , -0.38229934, ..., -0.37727737,
#         -1.6427003 ,  0.54810709],
#        [-0.85657842, -1.03249787, -1.02080349, ..., -0.11895088,
#          0.78445936,  1.80204991],
#        [ 0.32260746,  0.52834764, -0.17797801, ...,  1.28339295,
#          0.24509055, -0.70583574],
#        ...,
#        [-0.85657842, -0.61373444, -0.07581735, ...,  0.06556805,
#         -0.02459386,  0.54810709],
#        [-0.85657842, -0.8516682 , -0.790942  , ..., -0.08204709,
#          1.59351257,  0.54810709],
#        [ 1.50179333,  1.17552748,  1.15011062, ..., -0.37727737,
#         -0.83364708, -0.70583574]])
